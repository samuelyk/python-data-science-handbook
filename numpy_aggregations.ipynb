# %%
import numpy as np

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jakevdp/PythonDataScienceHandbook/refs/heads/master/notebooks/data/president_heights.csv"

df = pd.read_csv(url)

print(df.head())
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183
